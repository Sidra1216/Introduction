# %% [markdown]
# # Basic Image Processing

# %% [markdown]
# ## 1. Show Image

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('models_pictures/saba_qamar_01.jfif')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

img_chikuwa = io.imread('models_pictures/saba_qamar_01.jfif')

plt.imshow(img_chikuwa)
plt.show()

# %% [markdown]
# ## 2. Show 2D Histogram of Image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 画像の読み込み
img = cv2.imread('models_pictures/saba_qamar_01.jfif', 0)

# ヒストグラムの取得
img_hist_cv = cv2.calcHist([img], [0], None, [256], [0, 256])

# ヒストグラムの表示
plt.plot(img_hist_cv)
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage import io

img_dark = io.imread('models_pictures/saba_qamar_01.jfif')
plt.imshow(img_dark); plt.show()
plt.hist(img_dark.ravel(), bins=255, rwidth=0.8, range=(0, 255))
plt.show()

# %% [markdown]
# ## 3. Get 2D Histogram RGB(maximum value) of Multiple Images

# %%
#OpenCVでRGBのヒストグラムを取得

def RGB_img(path):
    
    import numpy as np
    import matplotlib.pyplot as plt
    import cv2
    from skimage import io

    img = cv2.imread(path)
    b, g, r = img[:,:,0], img[:,:,1], img[:,:,2]

    hist_b = cv2.calcHist([b],[0],None,[256],[0,256])
    hist_g = cv2.calcHist([g],[0],None,[256],[0,256])
    hist_r = cv2.calcHist([r],[0],None,[256],[0,256])

    plt.plot(hist_r, color='r', label="r")
    plt.plot(hist_g, color='g', label="g")
    plt.plot(hist_b, color='b', label="b")
    plt.legend()
    plt.show() 
    
    return hist_r,hist_g, hist_b

# %%
# read multiple images

import glob
image_path_list = glob.glob("models_pictures/*")

# %%
# You can use the #enumerate function to retrieve the element index and the element at the same time.

import matplotlib.pyplot as plt
from skimage import io

for i, j in enumerate(image_path_list):
    plt.title('Model_'+ str(i+1))
    plt.imshow(io.imread(j))
    plt.show()
    r,g,b = RGB_img(j)
    print("r",max(r[0:250]),"g",max(g[0:250]),"b",max(g[0:250]))
# Out:
# r [1317.] g [1134.] b [1134.]
# r [1180.] g [908.] b [908.]
